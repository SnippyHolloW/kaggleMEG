# %% [markdown]
# ### Importing, + what is the data like

# %%
from scipy.io import loadmat
from pylab import imshow, show
d = loadmat("data/train_subject01.mat")  # get it from https://www.kaggle.com/c/decoding-the-human-brain/download/train_01_06.zip
print d.keys()
print d['sfreq']
print d['X'].shape  # (N_TRIALS, N_ELECTRODES, N_TIMESTAMPS)
firstline = d['X'][0]
imshow(firstline)
# Out:
# ['tmin', 'tmax', 'sfreq', '__header__', '__globals__', 'y', 'X', '__version__']
# [[ 250.]]
# (594, 306, 375)

# %% [markdown]
# ### Filtering down the temporal signal

# %%
ham = np.hamming(9)  # TODO
from scipy import signal
res = signal.decimate(firstline, 4)
print res.shape
imshow(res)
# Out:
# (306, 94)

# %% [markdown]
# ### Electrodes means over timesteps

# %%
plot(firstline.sum(axis=-1))  # sum on all the timestep: shows electrodes means for the first trial

# %%
X = d['X']
y = d['y'].ravel()
print X[y==1].shape
tmean1 = X[y==1].sum(axis=2)
plot(tmean1.sum(axis=0))
# Out:
# (297, 306, 375)

# %%
tmean0 = X[y==0].sum(axis=2)
plot(tmean0.sum(axis=0))

# %% [markdown]
# ### Electrodes means over trials

# %%
cmean1 = X[y==1].sum(axis=0)
imshow(cmean1)

# %%
cmean0 = X[y==0].sum(axis=0)
imshow(cmean0)
